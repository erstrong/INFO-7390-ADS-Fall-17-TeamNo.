# %%
import urllib.request
import json

data = {
        "Inputs": {
                "input1":
                [
                    {
                            'loan_amnt': "27050",   
                            'term': "36",   
                            'emp_length': "10",   
                            'annual_inc': "55000",   
                            'dti': "22.87",   
                            'delinq_2yrs': "0",   
                            'fico_range_low': "730",   
                            'mths_since_last_delinq': "195",   
                            'open_acc': "14",   
                            'revol_bal': "36638",   
                            'revol_util': "61.2",   
                            'total_acc': "27",   
                            'collections_12_mths_ex_med': "0",   
                            'policy_code': "1",   
                            'application_type': "0",   
                            'tot_cur_bal': "114834",   
                            'bc_util': "53.9",   
                            'chargeoff_within_12_mths': "0",   
                            'mo_sin_old_il_acct': "117",   
                            'mo_sin_rcnt_tl': "6",   
                            'mort_acc': "4",   
                            'mths_since_recent_bc': "16",   
                            'mths_since_recent_inq': "8",   
                            'num_accts_ever_120_pd': "0",   
                            'num_actv_bc_tl': "2",   
                            'num_actv_rev_tl': "4",   
                            'num_bc_tl': "8",   
                            'num_il_tl': "8",   
                            'num_rev_accts': "15",   
                            'num_rev_tl_bal_gt_0': "4",   
                            'num_sats': "14",   
                            'num_tl_30dpd': "0",   
                            'num_tl_90g_dpd_24m': "0",   
                            'num_tl_op_past_12m': "1",   
                            'percent_bc_gt_75': "25",   
                            'pub_rec_bankruptcies': "0",   
                            'tax_liens': "0",   
                            'total_bc_limit': "35700",   
                            'home_ANY': "0",   
                            'home_MORTGAGE': "0",   
                            'home_NONE': "0",   
                            'home_OTHER': "0",   
                            'home_OWN': "1",   
                            'home_RENT': "0",   
                            'st_AK': "0",   
                            'st_AL': "0",   
                            'st_AR': "0",   
                            'st_AZ': "0",   
                            'st_CA': "0",   
                            'st_CO': "0",   
                            'st_CT': "0",   
                            'st_DC': "0",   
                            'st_DE': "0",   
                            'st_FL': "0",   
                            'st_GA': "0",   
                            'st_HI': "0",   
                            'st_IA': "0",   
                            'st_ID': "0",   
                            'st_IL': "0",   
                            'st_IN': "0",   
                            'st_KS': "0",   
                            'st_KY': "0",   
                            'st_LA': "0",   
                            'st_MA': "0",   
                            'st_MD': "0",   
                            'st_ME': "0",   
                            'st_MI': "1",   
                            'st_MN': "0",   
                            'st_MO': "0",   
                            'st_MS': "0",   
                            'st_MT': "0",   
                            'st_NC': "0",   
                            'st_ND': "0",   
                            'st_NE': "0",   
                            'st_NH': "0",   
                            'st_NJ': "0",   
                            'st_NM': "0",   
                            'st_NV': "0",   
                            'st_NY': "0",   
                            'st_OH': "0",   
                            'st_OK': "0",   
                            'st_OR': "0",   
                            'st_PA': "0",   
                            'st_RI': "0",   
                            'st_SC': "0",   
                            'st_SD': "0",   
                            'st_TN': "0",   
                            'st_TX': "0",   
                            'st_UT': "0",   
                            'st_VA': "0",   
                            'st_VT': "0",   
                            'st_WA': "0",   
                            'st_WI': "0",   
                            'st_WV': "0",   
                            'st_WY': "0",   
                    }
                ],
        },
    "GlobalParameters":  {
    }
}

body = str.encode(json.dumps(data))

url = 'https://ussouthcentral.services.azureml.net/workspaces/d020a5f18cd24fd6b8f4635f6a20d6da/services/11bb6987f5ac435da427593e7d3f390b/execute?api-version=2.0&format=swagger'
api_key = 'qbq5zT5bAGaTTzrrqhB9avrLjgOpdkVJ3F4ExEEpo5gUt2w5wvX//PT6ZMdETF5eBKuS9FlseawKOMyHop9LeQ==' # Replace this with the API key for the web service
headers = {'Content-Type':'application/json', 'Authorization':('Bearer '+ api_key)}

req = urllib.request.Request(url, body, headers)

try:
    response = urllib.request.urlopen(req)

    result = response.read()
    print(result)
except urllib.error.HTTPError as error:
    print("The request failed with status code: " + str(error.code))

    # Print the headers - they include the requert ID and the timestamp, which are useful for debugging the failure
    print(error.info())
    print(json.loads(error.read().decode("utf8", 'ignore')))
# Out:
# b'{"Results":{"output1":[{"loan_amnt":"27050","term":"36","emp_length":"10","annual_inc":"55000","dti":"22.87","delinq_2yrs":"0","fico_range_low":"730","mths_since_last_delinq":"195","open_acc":"14","revol_bal":"36638","revol_util":"61.2","total_acc":"27","collections_12_mths_ex_med":"0","policy_code":"1","application_type":"0","tot_cur_bal":"114834","bc_util":"53.9","chargeoff_within_12_mths":"0","mo_sin_old_il_acct":"117","mo_sin_rcnt_tl":"6","mort_acc":"4","mths_since_recent_bc":"16","mths_since_recent_inq":"8","num_accts_ever_120_pd":"0","num_actv_bc_tl":"2","num_actv_rev_tl":"4","num_bc_tl":"8","num_il_tl":"8","num_rev_accts":"15","num_rev_tl_bal_gt_0":"4","num_sats":"14","num_tl_30dpd":"0","num_tl_90g_dpd_24m":"0","num_tl_op_past_12m":"1","percent_bc_gt_75":"25","pub_rec_bankruptcies":"0","tax_liens":"0","total_bc_limit":"35700","home_ANY":"0","home_MORTGAGE":"0","home_NONE":"0","home_OTHER":"0","home_OWN":"1","home_RENT":"0","st_AK":"0","st_AL":"0","st_AR":"0","st_AZ":"0","st_
# ...
