# %%
 
import urllib.request
import json

data = {
        "Inputs": {
                "input1":
                [
                    {
                            'loan_amnt': "6000",   
                            'term': "36",   
                            'emp_length': "1",   
                            'annual_inc': "70000",   
                            'dti': "25.14",   
                            'delinq_2yrs': "0",   
                            'fico_range_low': "700",   
                            'mths_since_last_delinq': "195",   
                            'open_acc': "20",   
                            'revol_bal': "27233",   
                            'revol_util': "64.2",   
                            'total_acc': "37",   
                            'collections_12_mths_ex_med': "0",   
                            'policy_code': "1",   
                            'application_type': "0",   
                            'tot_cur_bal': "215466",   
                            'bc_util': "89.1",   
                            'chargeoff_within_12_mths': "0",   
                            'mo_sin_old_il_acct': "199",   
                            'mo_sin_rcnt_tl': "5",   
                            'mort_acc': "3",   
                            'mths_since_recent_bc': "26",   
                            'mths_since_recent_inq': "5",   
                            'num_accts_ever_120_pd': "0",   
                            'num_actv_bc_tl': "10",   
                            'num_actv_rev_tl': "12",   
                            'num_bc_tl': "14",   
                            'num_il_tl': "11",   
                            'num_rev_accts': "23",   
                            'num_rev_tl_bal_gt_0': "12",   
                            'num_sats': "20",   
                            'num_tl_30dpd': "0",   
                            'num_tl_90g_dpd_24m': "0",   
                            'num_tl_op_past_12m': "4",   
                            'percent_bc_gt_75': "80",   
                            'pub_rec_bankruptcies': "0",   
                            'tax_liens': "0",   
                            'total_bc_limit': "29000",   
                            'home_ANY': "0",   
                            'home_MORTGAGE': "1",   
                            'home_NONE': "0",   
                            'home_OTHER': "0",   
                            'home_OWN': "0",   
                            'home_RENT': "0",   
                            'st_AK': "0",   
                            'st_AL': "0",   
                            'st_AR': "0",   
                            'st_AZ': "0",   
                            'st_CA': "0",   
                            'st_CO': "0",   
                            'st_CT': "0",   
                            'st_DC': "0",   
                            'st_DE': "0",   
                            'st_FL': "0",   
                            'st_GA': "0",   
                            'st_HI': "0",   
                            'st_IA': "0",   
                            'st_ID': "0",   
                            'st_IL': "0",   
                            'st_IN': "0",   
                            'st_KS': "0",   
                            'st_KY': "0",   
                            'st_LA': "0",   
                            'st_MA': "0",   
                            'st_MD': "0",   
                            'st_ME': "0",   
                            'st_MI': "0",   
                            'st_MN': "0",   
                            'st_MO': "0",   
                            'st_MS': "0",   
                            'st_MT': "0",   
                            'st_NC': "1",   
                            'st_ND': "0",   
                            'st_NE': "0",   
                            'st_NH': "0",   
                            'st_NJ': "0",   
                            'st_NM': "0",   
                            'st_NV': "0",   
                            'st_NY': "0",   
                            'st_OH': "0",   
                            'st_OK': "0",   
                            'st_OR': "0",   
                            'st_PA': "0",   
                            'st_RI': "0",   
                            'st_SC': "0",   
                            'st_SD': "0",   
                            'st_TN': "0",   
                            'st_TX': "0",   
                            'st_UT': "0",   
                            'st_VA': "0",   
                            'st_VT': "0",   
                            'st_WA': "0",   
                            'st_WI': "0",   
                            'st_WV': "0",   
                            'st_WY': "0",   
                    }
                ],
        },
    "GlobalParameters":  {
    }
}

body = str.encode(json.dumps(data))

url = 'https://ussouthcentral.services.azureml.net/workspaces/d020a5f18cd24fd6b8f4635f6a20d6da/services/0c8b47a279414a4e96c0df0df9756c18/execute?api-version=2.0&format=swagger'
api_key = 's0edKJtbPX2b5Gi4Q6cuZmi8kRoysOnBDPuyCdLQS78ZruwSvDHuQAbbK/q9wT5eOCpKdh+dy4pMZMtgQCzVQw==' # Replace this with the API key for the web service
headers = {'Content-Type':'application/json', 'Authorization':('Bearer '+ api_key)}

req = urllib.request.Request(url, body, headers)

try:
    response = urllib.request.urlopen(req)

    result = response.read()
    print(result)
except urllib.error.HTTPError as error:
    print("The request failed with status code: " + str(error.code))

    # Print the headers - they include the requert ID and the timestamp, which are useful for debugging the failure
    print(error.info())
    print(json.loads(error.read().decode("utf8", 'ignore')))
# Out:
# b'{"Results":{"output1":[{"loan_amnt":"6000","term":"36","emp_length":"1","annual_inc":"70000","dti":"25.14","delinq_2yrs":"0","fico_range_low":"700","mths_since_last_delinq":"195","open_acc":"20","revol_bal":"27233","revol_util":"64.2","total_acc":"37","collections_12_mths_ex_med":"0","policy_code":"1","application_type":"0","tot_cur_bal":"215466","bc_util":"89.1","chargeoff_within_12_mths":"0","mo_sin_old_il_acct":"199","mo_sin_rcnt_tl":"5","mort_acc":"3","mths_since_recent_bc":"26","mths_since_recent_inq":"5","num_accts_ever_120_pd":"0","num_actv_bc_tl":"10","num_actv_rev_tl":"12","num_bc_tl":"14","num_il_tl":"11","num_rev_accts":"23","num_rev_tl_bal_gt_0":"12","num_sats":"20","num_tl_30dpd":"0","num_tl_90g_dpd_24m":"0","num_tl_op_past_12m":"4","percent_bc_gt_75":"80","pub_rec_bankruptcies":"0","tax_liens":"0","total_bc_limit":"29000","home_ANY":"0","home_MORTGAGE":"1","home_NONE":"0","home_OTHER":"0","home_OWN":"0","home_RENT":"0","st_AK":"0","st_AL":"0","st_AR":"0","st_AZ":"0","
# ...
