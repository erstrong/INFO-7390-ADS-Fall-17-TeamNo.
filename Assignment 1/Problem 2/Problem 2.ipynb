# %% [markdown]
# # Processing the EDGAR Data Set

# %% [markdown]
# Given a year, get data for the first day of the month for every month in the year. Example URL: http://www.sec.gov/dera/data/Public-EDGAR-log-file-data/2003/Qtr1/log20030101.zip

# %% [markdown]
# ### Generate URLs

# %%
year = 2005 # environmental variable

# %%
url_base = 'http://www.sec.gov/dera/data/Public-EDGAR-log-file-data/'

# %%
url_mid = '/log' + str(year)

# %%
url_final = '01.zip'

# %%
urls = []
# use range to get all 12 months
for x in range(1,13):
    if (x < 4):
        urls.append(url_base + str(year) + '/Qtr1' + url_mid + '0' + str(x) + url_final)
    elif (x >=4 and x < 7):
        urls.append(url_base + str(year) + '/Qtr2' + url_mid + '0' + str(x) + url_final)
    elif (x >= 7 and x < 10):
        urls.append(url_base + str(year) + '/Qtr3' + url_mid + '0' + str(x) + url_final)
    else:
        urls.append(url_base + str(year) + '/Qtr4' + url_mid + str(x) + url_final)
        
print(urls)
# Out:
# ['http://www.sec.gov/dera/data/Public-EDGAR-log-file-data/2005/Qtr1/log20050101.zip', 'http://www.sec.gov/dera/data/Public-EDGAR-log-file-data/2005/Qtr1/log20050201.zip', 'http://www.sec.gov/dera/data/Public-EDGAR-log-file-data/2005/Qtr1/log20050301.zip', 'http://www.sec.gov/dera/data/Public-EDGAR-log-file-data/2005/Qtr2/log20050401.zip', 'http://www.sec.gov/dera/data/Public-EDGAR-log-file-data/2005/Qtr2/log20050501.zip', 'http://www.sec.gov/dera/data/Public-EDGAR-log-file-data/2005/Qtr2/log20050601.zip', 'http://www.sec.gov/dera/data/Public-EDGAR-log-file-data/2005/Qtr3/log20050701.zip', 'http://www.sec.gov/dera/data/Public-EDGAR-log-file-data/2005/Qtr3/log20050801.zip', 'http://www.sec.gov/dera/data/Public-EDGAR-log-file-data/2005/Qtr3/log20050901.zip', 'http://www.sec.gov/dera/data/Public-EDGAR-log-file-data/2005/Qtr4/log20051001.zip', 'http://www.sec.gov/dera/data/Public-EDGAR-log-file-data/2005/Qtr4/log20051101.zip', 'http://www.sec.gov/dera/data/Public-EDGAR-log-file-data/2005/Qtr4/log20051201.zip']

# %% [markdown]
# The log files are large, so we will read them from the zip files instead of extracting them

# %%
import zipfile
import requests
from io import StringIO,BytesIO
import pandas as pd
from pandas import *
import re
import numpy
import scipy
from scipy import stats

# %%
column_names = ['ip','date','time','zone','cik','accession','doc/extention','code','filesize','idx','norefer','noagent','find','crawler','browser']
full_logs = pd.DataFrame(columns=column_names)

# %% [markdown]
# Default Values:
# * ip: unknown
# * date: derive from file date
# * time: unknown
# * zone: 0
# * cik: unknown
# * accession: unknown
# * doc: unknown
# * code: unknown
# * size: mean
# * idx: 0
# * noreferer: 0
# * noagent: 0
# * find: 0
# * crawler: 0
# * browser: unknown
#
# Numeric defaults are based on the README that comes with each log

# %%
dataframe_collection = []
for url in urls:
    #print url
    r = requests.get(url, stream=True)
    z = zipfile.ZipFile(BytesIO(r.content))
    st = pd.read_csv(z.open(url[-15:-3]+'csv'))
    
    # Handle Missing Data
    
    # Replace missing numeric values and categorical that have default 0
    st.fillna({'zone': 0, 'idx': 0,'noreferer': 0,'noagent': 0,'find': 0,'crawler': 0}, inplace=True)
    # Replace missing categorical values
    st.fillna({'ip':'unknown', 'time':'unknown','cik':'unknown','accession':'unknown','code':'unknown','browser':'unknown'}, inplace=True)
    st.fillna({'doc':'unknown', 'extention':'unknown'}, inplace=True)
    # Replace missing dates from file name
    date_formatted = url[-12:-8]+'-'+url[-8:-6] + '-' + url[-6:-4]
    st.fillna({'date': date_formatted}, inplace=True)
    # Replace missing file sizes with mean
    st.fillna({'size': scipy.mean(st['size'])}, inplace=True)
    dataframe_collection.append(st)

# %%
nullvaluesindf=[]
alldfs=[]
for i in range(0,len(dataframe_collection)):
    nullvaluesindf.append(pd.isnull(dataframe_collection[i]).sum()>0)
    alldfs.append(nullvaluesindf)

# %%
dataframe_collection[0].describe()
# Out:
#            zone           cik           code          size            idx  \
# count  168657.0  1.686570e+05  168657.000000  1.686570e+05  168657.000000
# mean      500.0  8.557709e+05     219.970639  1.758193e+05       0.464143
# std         0.0  3.725466e+05      41.105357  5.333279e+05       0.498714
# min       500.0  2.000000e+01     200.000000  0.000000e+00       0.000000
# 25%       500.0  7.751810e+05     200.000000  2.648000e+03       0.000000
# 50%       500.0  9.293510e+05     200.000000  4.673000e+03       0.000000
# 75%       500.0  1.104730e+06     200.000000  1.758193e+05       1.000000
# max       500.0  1.313239e+06     404.000000  3.810365e+07       1.000000
#
#              norefer        noagent           find        crawler
# count  168657.000000  168657.000000  168657.000000  168657.000000
# mean        0.849725       0.069004       0.605946       0.040485
# std         0.357342       0.253462       2.065830       0.197093
# min         0.000000       0.000000       0.000000       0.000000
# 25%         1.000000       0.000000       0.000000       0.000000
# 50%         1.000000       0.000000       0.000000       0.000000
# 75%         1.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000      10.000000       1.000000

# %%
dataframe_collection[0]['accession'].value_counts()
# Out:
# 0001193125-04-221736    727
# 0001125282-04-006596    726
# 0000891618-04-001402    726
# 0001193125-04-221735    726
# 0001193125-04-221734    724
# 0000882377-04-002779    724
# 0001071787-04-001609    723
# 0001071787-04-001608    722
# 0000950144-04-012484    722
# 0000922423-04-002111    722
# 0001071787-04-001610    722
# 0000909334-04-000362    721
# 0000882377-04-002780    721
# 0001117768-03-000002    322
# 0001214305-04-000013    273
# 0001312289-04-000002    213
# 0001254639-04-000012    211
# 0001209191-04-059962    197
# 0000909450-04-000102    192
# 0001047469-02-004136    162
# 0001047469-03-005185    153
# 0000950127-04-001171    128
# 0001047469-04-017079    124
# 0001047469-02-008768    120
# 0000945234-04-000784    117
# 0001047469-04-014104    114
# 0001047469-03-005454    113
# 0001047469-03-002575    111
# 0001169232-04-006220    110
# 0001047469-03-013785    110
#                        ...
# 0000950109-00-001367      1
# 0000950129-02-004400      1
# 0000906648-03-000080      1
# 0000950112-99-000719      1
# 0000891804-03-000918      1
# 0000717809-99-000005      1
# 0000021344-04-000235      1
# 0000905148-03-004402      1
# 0000950152-99-003735      1
# 0001047469-03-025343      1
# 0000903112-00-000352      1
# 0000875626-99-000493      1
# 0000827052-04-000154      1
# 0000950005-00-000719      1
# 0000088498-03-000002      1
# 9999999997-04-027660      1
# 0001193125-03-037674      1
# 0001029869-99-000467      1
# 0001012709-01-000127      1
# 0000945094-04-000345      1
# 0000899681-02-000310      1
# 0000950109-03-001337      1
# 0000931763-01-500395      1
# 0001016964-00-000027      1
# 0001104659-03-026976      1
# 0000771726-03-000162      1
# 0000935703-04-000106      1
# 0000910069-01-000044      1
# 0000950152-99-008568      1
# 0000932440-02-000450      1
# Name: accession, Length: 77169, dtype: int64

# %% [markdown]
# For each log file:
# * Handle missing data xx
# * Compute summary metrics (Decide which ones)
# * Check for any observable anomalies
# * Your program should log all the operations (with time stamps) into a log file.
# * Compile all the data and summaries of the 12 files into one file

# %%
for i in range(0,len(dataframe_collection)):
    df=dataframe_collection[i]
    full_logs=pd.concat([full_logs,df])

# %%
full_logs
# Out:
#                    accession  browser        cik   code  crawler        date  \
# 0       0000879123-04-000076      mie   933239.0  200.0      0.0  2005-01-01
# 1       0001209191-04-059913      mie   932696.0  200.0      0.0  2005-01-01
# 2       0000928022-04-000071      mie   928022.0  200.0      0.0  2005-01-01
# 262448  0000038777-05-000047  unknown    38777.0  200.0      0.0  2005-12-01
# 262449  0000950134-05-003127      win   929987.0  200.0      0.0  2005-12-01
# 262450  0001144204-05-037158      win  1051059.0  200.0      0.0  2005-12-01
# 262451  0000946644-05-000018      win   946644.0  200.0      0.0  2005-12-01
# 262452  0000950153-05-003053      win  1323630.0  200.0      0.0  2005-12-01
# 262453  0001295345-05-000048      win   719729.0  200.0      0.0  2005-12-01
# 262454  0000950137-05-014199      win   712034.0  200.0      0.0  2005-12-01
# 262455  0000891618-05-000364      win  1294371.0  200.0      0.0  2005-12-01
# 262456  0000315066-05-002795      win  1032033.0  200.0      0.0  2005-12-01
# 262457  0001193125-05-045548      win  1050797.0  200.0      0.0  2005-12-01
# 262458  0001181431-05-063426      win   879206.0  200.0      0.0  2005-12-01
# 262459  0000950133-04-004367      win   854875.0  200.0      0.0  2005-12-01
# 262460  0001295345-05-000060      win   719729.0  200.0      0.0  2005-12-01
# 262461  0000038777-05-000055  unknown    38777.0  200.0      0.0  2005-12-01
# 262462  0001295345-05-000060      win   719729.0  200.0      0.0  2005-12-01
# 262463  0001264794-05-000003      win  1264794.0  200.0      0.0  2005-12-01
#
#        doc/extention                      extention filesize  find  idx  \
# 0                NaN                     -index.htm      NaN   0.0  1.0
# 1                NaN                     -index.htm      NaN   0.0  1.0
# 2                NaN                     may327.xml      NaN   0.0  0.0
# 3                NaN                      edgar.xml      NaN   0.0  0.0
# 4                NaN                primary_doc.xml      NaN   0.0  0.0
# 5                NaN                           .txt      NaN   0.0  0.0
# 6                NaN                     cal326.xml      NaN   0.0  0.0
# 7                NaN                     -index.htm      NaN   0.0  1.0
# 8                NaN                     -index.htm      NaN   0.0  1.0
# 9                NaN                           .txt      NaN   0.0  0.0
# 10               NaN                     -index.htm      NaN   0.0  1.0
# 11               NaN                           .txt      NaN   0.0  0.0
# 12               NaN                     -index.htm      NaN   0.0  1.0
# 13               NaN                   rrd62894.xml      NaN   0.0  0.0
# 14               NaN             fullerform4_ex.xml      NaN   0.0  0.0
# 15               NaN                      edgar.xml      NaN   0.0  0.0
# 16               NaN                     smi329.xml      NaN   0.0  0.0
# 17               NaN                     -index.htm      NaN   0.0  1.0
# 18               NaN                           .txt      NaN   0.0  0.0
# 19               NaN                     -index.htm      NaN   0.0  1.0
# 20               NaN                           .txt      NaN   0.0  0.0
# 21               NaN                     may327.xml      NaN   0.0  0.0
# 22               NaN                           .txt      NaN   0.0  0.0
# 23               NaN                     -index.htm      NaN   0.0  1.0
# 24               NaN                     -index.htm      NaN   0.0  1.0
# 25               NaN                     -index.htm      NaN   0.0  1.0
# 26               NaN                     sch328.xml      NaN   0.0  0.0
# 27               NaN                           .txt      NaN   0.0  0.0
# 28               NaN                   edgardoc.xml      NaN   0.0  0.0
# 29               NaN                      wil13.xml      NaN   0.0  0.0
# ...              ...                            ...      ...   ...  ...
# 262434           NaN     f97751b2exv99wxayx106y.txt      NaN   9.0  0.0
# 262435           NaN                           .txt      NaN   1.0  0.0
# 262436           NaN                     -index.htm      NaN   1.0  1.0
# 262437           NaN                     sac486.xml      NaN   0.0  0.0
# 262438           NaN                 g92281e8vk.htm      NaN   9.0  0.0
# 262439           NaN                     -index.htm      NaN   1.0  1.0
# 262440           NaN                     -index.htm      NaN   1.0  1.0
# 262441           NaN                     ike496.xml      NaN   0.0  0.0
# 262442           NaN                     -index.htm      NaN   1.0  1.0
# 262443           NaN                     -index.htm      NaN   1.0  1.0
# 262444           NaN                    file001.htm      NaN   9.0  0.0
# 262445           NaN                     -index.htm      NaN   4.0  1.0
# 262446           NaN                           .txt      NaN   1.0  0.0
# 262447           NaN                     -index.htm      NaN   1.0  1.0
# 262448           NaN                     kra497.xml      NaN   0.0  0.0
# 262449           NaN                c91953e10vk.htm      NaN   9.0  0.0
# 262450           NaN  v030138_dialoggroup-10qsb.txt      NaN   9.0  0.0
# 262451           NaN                     -index.htm      NaN   0.0  1.0
# 262452           NaN              p70473a3sv1za.htm      NaN   9.0  0.0
# 262453           NaN                     -index.htm      NaN   1.0  1.0
# 262454           NaN            c00350a1sc13dza.htm      NaN   9.0  0.0
# 262455           NaN            f07215a1e10vkza.htm      NaN   9.0  0.0
# 262456           NaN                     -index.htm      NaN   1.0  1.0
# 262457           NaN                     -index.htm      NaN   1.0  1.0
# 262458           NaN        xslF345X02/rrd97449.xml      NaN   9.0  0.0
# 262459           NaN                w67902ke425.htm      NaN   9.0  0.0
# 262460           NaN                     -index.htm      NaN   1.0  1.0
# 262461           NaN                     cro501.xml      NaN   0.0  0.0
# 262462           NaN                   clyw-8ka.htm      NaN   9.0  0.0
# 262463           NaN                     -index.htm      NaN   1.0  1.0
#
#                      ip  noagent  norefer       size      time   zone
# 0         68.70.131.gjc      0.0      1.0     2963.0  00:00:00  500.0
# 1         68.70.131.gjc      0.0      1.0     2579.0  00:00:00  500.0
# 2         68.70.131.gjc      0.0      1.0    12615.0  00:00:00  500.0
# 3         68.70.131.gjc      0.0      1.0    10032.0  00:00:00  500.0
# 4         68.70.131.gjc      0.0      1.0     8307.0  00:00:00  500.0
# 5         68.70.131.gjc      0.0      1.0     5558.0  00:00:00  500.0
# 6         68.70.131.gjc      0.0      1.0    13899.0  00:00:00  500.0
# 7         68.70.131.gjc      0.0      1.0     3074.0  00:00:00  500.0
# 8         68.70.131.gjc      0.0      1.0     2724.0  00:00:00  500.0
# 9         68.70.131.gjc      0.0      1.0    14260.0  00:00:00  500.0
# 10        68.70.131.gjc      0.0      1.0     2700.0  00:00:00  500.0
# 11        68.70.131.gjc      0.0      1.0    10261.0  00:00:00  500.0
# 12        68.70.131.gjc      0.0      1.0     2730.0  00:00:00  500.0
# 13        68.70.131.gjc      0.0      1.0    17329.0  00:00:00  500.0
# 14        68.70.131.gjc      0.0      1.0     5838.0  00:00:00  500.0
# 15        68.70.131.gjc      0.0      1.0    10032.0  00:00:00  500.0
# 16        68.70.131.gjc      0.0      1.0    12663.0  00:00:01  500.0
# 17        68.70.131.gjc      0.0      1.0     2700.0  00:00:01  500.0
# 18        68.70.131.gjc      0.0      1.0     6073.0  00:00:01  500.0
# 19        68.70.131.gjc      0.0      1.0     2579.0  00:00:01  500.0
