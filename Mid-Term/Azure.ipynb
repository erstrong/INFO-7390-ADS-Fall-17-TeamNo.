# %%
import urllib.request
import json

data = {
        "Inputs": {
                "input1":
                [
                    {
                            '2016': "1",   
                            '2017': "0",   
                            'parcelid': "17073783",   
                            'airconditioningtypeid': "5",   
                            'bedroomcnt': "3",   
                            'buildingqualitytypeid': "6.015460983643268",   
                            'calculatedbathnbr': "2.5",   
                            'calculatedfinishedsquarefeet': "1264",   
                            'fips': "6111",   
                            'fireplacecnt': "0",   
                            'fullbathcnt': "2",   
                            'garagecarcnt': "2",   
                            'garagetotalsqft': "434",   
                            'hashottuborspa': "0",   
                            'heatingorsystemtypeid': "2",   
                            'latitude': "34.303597",   
                            'longitude': "-119.287236",   
                            'lotsizesquarefeet': "1735",   
                            'poolcnt': "0",   
                            'propertylandusetypeid': "265",   
                            'rawcensustractandblock': "61110022003007",   
                            'roomcnt': "5",   
                            'unitcnt': "1",   
                            'yearbuilt': "1986",   
                            'numberofstories': "2",   
                            'fireplaceflag': "0",   
                            'structuretaxvaluedollarcnt': "115087",   
                            'taxvaluedollarcnt': "191811",   
                            'assessmentyear': "2015",   
                            'landtaxvaluedollarcnt': "76724",   
                            'taxamount': "2015.06",   
                            'taxdelinquencyflag': "0",   
                            'logerror': "0.0953",   
                            'transactiondate': "2016-01-27T00:00:00Z",   
                            'setyear': "2016",   
                            'pooltype': "0",   
                            'zipcode': "93001",   
                            '6037.0': "0",   
                            '6059.0': "0",   
                            '6111.0': "1",   
                            'ac_1.0': "0",   
                            'ac_3.0': "0",   
                            'ac_5.0': "1",   
                            'ac_9.0': "0",   
                            'ac_11.0': "0",   
                            'ac_13.0': "0",   
                            'heat_1.0': "0",   
                            'heat_2.0': "1",   
                            'heat_6.0': "0",   
                            'heat_7.0': "0",   
                            'heat_10.0': "0",   
                            'heat_11.0': "0",   
                            'heat_12.0': "0",   
                            'heat_13.0': "0",   
                            'heat_14.0': "0",   
                            'heat_18.0': "0",   
                            'heat_20.0': "0",   
                            'heat_24.0': "0",   
                            'pooltype_0': "1",   
                            'pooltype_2': "0",   
                            'pooltype_7': "0",   
                            'pooltype_10': "0",   
                    }
                ],
        },
    "GlobalParameters":  {
        'Append score columns to output': "true",
    }
}

body = str.encode(json.dumps(data))

url = 'https://ussouthcentral.services.azureml.net/workspaces/d020a5f18cd24fd6b8f4635f6a20d6da/services/6a85022d0ff0423cb8fdfe4dac2224ef/execute?api-version=2.0&format=swagger'
api_key = 'zZ+MVLzWHKNUIhzJ60X0QyWOkgwio22eI+60YFl2cnw78CQJn5s2auABAh0lUGrAAXFIr2flq7gN90zEb1l9SA==' # Replace this with the API key for the web service
headers = {'Content-Type':'application/json', 'Authorization':('Bearer '+ api_key)}

req = urllib.request.Request(url, body, headers)

try:
    response = urllib.request.urlopen(req)

    result = response.read()
    print(result)
except urllib.error.HTTPError as error:
    print("The request failed with status code: " + str(error.code))

    # Print the headers - they include the requert ID and the timestamp, which are useful for debugging the failure
    print(error.info())
    print(json.loads(error.read().decode("utf8", 'ignore')))
import urllib.request
import json

data = {
        "Inputs": {
                "input1":
                [
                    {
                            '2016': "1",   
                            '2017': "0",   
                            'parcelid': "17073783",   
                            'airconditioningtypeid': "5",   
                            'bedroomcnt': "3",   
                            'buildingqualitytypeid': "6.015460983643268",   
                            'calculatedbathnbr': "2.5",   
                            'calculatedfinishedsquarefeet': "1264",   
                            'fips': "6111",   
                            'fireplacecnt': "0",   
                            'fullbathcnt': "2",   
                            'garagecarcnt': "2",   
                            'garagetotalsqft': "434",   
                            'hashottuborspa': "0",   
                            'heatingorsystemtypeid': "2",   
                            'latitude': "34.303597",   
                            'longitude': "-119.287236",   
                            'lotsizesquarefeet': "1735",   
                            'poolcnt': "0",   
                            'propertylandusetypeid': "265",   
                            'rawcensustractandblock': "61110022003007",   
                            'roomcnt': "5",   
                            'unitcnt': "1",   
                            'yearbuilt': "1986",   
                            'numberofstories': "2",   
                            'fireplaceflag': "0",   
                            'structuretaxvaluedollarcnt': "115087",   
                            'taxvaluedollarcnt': "191811",   
                            'assessmentyear': "2015",   
                            'landtaxvaluedollarcnt': "76724",   
                            'taxamount': "2015.06",   
                            'taxdelinquencyflag': "0",   
                            'logerror': "0.0953",   
                            'transactiondate': "2016-01-27T00:00:00Z",   
                            'setyear': "2016",   
                            'pooltype': "0",   
                            'zipcode': "93001",   
                            '6037.0': "0",   
                            '6059.0': "0",   
                            '6111.0': "1",   
                            'ac_1.0': "0",   
                            'ac_3.0': "0",   
                            'ac_5.0': "1",   
                            'ac_9.0': "0",   
                            'ac_11.0': "0",   
                            'ac_13.0': "0",   
                            'heat_1.0': "0",   
                            'heat_2.0': "1",   
                            'heat_6.0': "0",   
                            'heat_7.0': "0",   
                            'heat_10.0': "0",   
                            'heat_11.0': "0",   
                            'heat_12.0': "0",   
                            'heat_13.0': "0",   
                            'heat_14.0': "0",   
                            'heat_18.0': "0",   
                            'heat_20.0': "0",   
                            'heat_24.0': "0",   
                            'pooltype_0': "1",   
                            'pooltype_2': "0",   
                            'pooltype_7': "0",   
                            'pooltype_10': "0",   
                    }
                ],
        },
    "GlobalParameters":  {
        'Append score columns to output': "true",
    }
}

body = str.encode(json.dumps(data))

url = 'https://ussouthcentral.services.azureml.net/workspaces/d020a5f18cd24fd6b8f4635f6a20d6da/services/6a85022d0ff0423cb8fdfe4dac2224ef/execute?api-version=2.0&format=swagger'
api_key = 'zZ+MVLzWHKNUIhzJ60X0QyWOkgwio22eI+60YFl2cnw78CQJn5s2auABAh0lUGrAAXFIr2flq7gN90zEb1l9SA==' # Replace this with the API key for the web service
headers = {'Content-Type':'application/json', 'Authorization':('Bearer '+ api_key)}

req = urllib.request.Request(url, body, headers)

try:
    response = urllib.request.urlopen(req)

    result = response.read()
    print(result)
except urllib.error.HTTPError as error:
    print("The request failed with status code: " + str(error.code))

    # Print the headers - they include the requert ID and the timestamp, which are useful for debugging the failure
    print(error.info())
    print(json.loads(error.read().decode("utf8", 'ignore')))
# Out:
# b'{"Results":{"output1":[{"calculatedfinishedsquarefeet":"1264","fireplacecnt":"0","latitude":"34.303597","fireplaceflag":"0","taxdelinquencyflag":"0","6111.0":"1","ac_5.0":"1","heat_14.0":"0","pooltype_0":"1","pooltype_2":"0","Scored Labels":"0.0135686423208678"}]}}'
# b'{"Results":{"output1":[{"calculatedfinishedsquarefeet":"1264","fireplacecnt":"0","latitude":"34.303597","fireplaceflag":"0","taxdelinquencyflag":"0","6111.0":"1","ac_5.0":"1","heat_14.0":"0","pooltype_0":"1","pooltype_2":"0","Scored Labels":"0.0135686423208678"}]}}'
